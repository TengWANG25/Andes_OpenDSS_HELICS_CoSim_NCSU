# %%
import andes

# %%
ss = andes.run(r"118_converted_from_UNCC_to_PSSE_format_MATCH_RAW_VN_ALLSHEETS_TAP_FROM_RAW.xlsx", default_config=True)
# Out:
# Working directory: "D:\Andes_OpenDSS_Cosim\benchmark_118_10_8500_Andes_OpenDSS\Andes_118_power_flow_test"
# > Loaded generated Python code in "C:\Users\twang48\.andes\pycode".
# Parsing input file "118_converted_from_UNCC_to_PSSE_format_MATCH_RAW_VN_ALLSHEETS_TAP_FROM_RAW.xlsx"...
# Input file parsed in 1.4088 seconds.
# System internal structure set up in 0.0175 seconds.
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0025 seconds.
# 0: |F(x)| = 0.3250445913
# 1: |F(x)| = 0.0002534214826
# 2: |F(x)| = 5.950878013e-09
# Converged in 3 iterations in 0.0032 seconds.
# Report saved to "118_converted_from_UNCC_to_PSSE_format_MATCH_RAW_VN_ALLSHEETS_TAP_FROM_RAW_out.txt" in 0.0019 seconds.
# -> Single process finished in 2.7974 seconds.

# %%
ss.TDS.plt
